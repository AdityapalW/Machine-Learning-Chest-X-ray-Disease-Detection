# %% [markdown]
# # Install Required Libraries
# Use pip to install any missing libraries, such as torchvision, if not already available in the Colab environment.

# %%
# Install required libraries using pip
# !pip install torch torchvision --quiet

# Verify installation
import torch
import torchvision

print("PyTorch version:", torch.__version__)
print("Torchvision version:", torchvision.__version__)

# %% [markdown]
# # Import Required Libraries
# Import necessary libraries, including torchvision.transforms and other dependencies.

# %%
# Import necessary libraries for image preprocessing
from torchvision import transforms
from PIL import Image
import os

# Ensure the libraries are imported successfully
print("Libraries imported successfully.")
